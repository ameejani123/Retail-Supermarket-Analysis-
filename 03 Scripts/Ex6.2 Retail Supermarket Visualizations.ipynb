# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
#Define path 
path=(r"C:\Users\hardjan\Retail Supermarket")

# %%
# Import Data set 

df = pd.read_csv(os.path.join(path,'02 Data', 'Prepared Data', 'samplesuperstore1.csv'), index_col = False)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'date'],
#       dtype='object')

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit       date
# 0      0.00   41.9136  2/27/2018
# ...

# %%
df.corr(numeric_only=True)
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sns.heatmap(df.corr(), annot=True)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
# create a subset for correlaiton 
sub=df[['Sales','Quantity','Discount','Profit']]

# %%
sub.corr()

# %% [markdown]
# ### 03.Create a correlation matrix heatmap (colored).
# Discuss what the coefficients in the plot mean in terms of the relationships between the variables.

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# #### Here we see that Sales having the correlation of 1 has a very perfect positive relationship.
# #### Quantity 0.2 : has a weak realtionship
# #### Discount-0.028 :has a strong negative relationship
# #### Profit:0.48 which means it has a weak Positive relationship

# %% [markdown]
# ##  04.Create a scatterplot (or plots) for the variables with the strongest correlations and examine the nature of their relationships..

# %% [markdown]
# #### Discuss what the coefficients in the plot mean in terms of the relationships between the variables.

# %%
#Create a scatterplot 
df.plot(kind="scatter",x="Sales",y="Profit", colormap="Set1",figsize=(8,8))

# %% [markdown]
# #### In this scatter plot we can clearly see that more sales does not mean more profit. It depends on discount as well. When Sales is high and there is low discount, the profit margin is higher

# %% [markdown]
# ### 05.Create a pair plot of the entire data set.

# %%
g = sns.pairplot(df)
# Out:
# C:\Users\hardjan\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\hardjan\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\hardjan\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ### 06.Create a categorical plot and interpret the results.

# %%
# Create a categorical plot in seaborn using the price categories created above
sns.set(style="ticks")
g = sns.catplot(x="Profit", y="Sales",data=df)
# Out:
# C:\Users\hardjan\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\hardjan\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Profit is not affected that much by more Sales Quantity.

# %%
# Use a histogram to visualize the distribution of the variables. 
# This way, you can determine sensible categories for the sales ranges. 
# You don't want to end up with too few observations in any one of the categories.
# The argument "kde" add a line that encompasses the distribution

sns.histplot(df['Discount'], bins = 10, kde = True)
# Out:
# C:\Users\hardjan\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Discount', ylabel='Count'>

# %%
sns.histplot(df['Sales'], bins = 20, kde = True)
# Out:
# C:\Users\hardjan\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.histplot(df['Profit'], bins = 50, kde = True)

# %%
sns.histplot(df['Quantity'], bins = 20, kde = True)

# %%
# create a discount category
df.loc[df['Discount'] < 0.3,'Discount_Category']= 'Low Discount'
df.loc[df['Discount'] >= 0.3,'Discount_Category']= 'High Discount'

# %%
df['Discount_Category'].value_counts(dropna=False)

# %%
sns.set(style="ticks")
g=sns.relplot( X="Discount",Y="Profit", hue="Discount_Category", Data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 sns.set(style="ticks")
# ----> 2 g=sns.relplot( X="Discount",Y="Profit", hue="Discount_Category", Data=df)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\seaborn\relational.py:862, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     859     kwargs.pop("ax")
#     861 # Use the full dataset to map the semantics
# --> 862 p = plotter(
#     863     data=data,
#     864     variables=plotter.get_semantics(locals()),
#     865     legend=legend,
#     866 )
#     867 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     868 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %%
## 1.	Which segment is doing pretty well?
sns.histplot(df['Segment'], bins = 20, )

# %% [markdown]
# ### In the chart above we can clearly see that the Concumer Segment is doing fairly good among the other segmenzts (Corporate and Home Office)

# %%
# Which are the top categories in the Supermarket?
sns.histplot(df['Category'], bins = 20, )

# %% [markdown]
# ### Office Supplies Category is the highest Contributor to the Sales.

# %%
sns.histplot(df['Ship Mode'], bins = 20, )

# %% [markdown]
# ### the preferred shipping mode is the Standard Class Mode.

# %% [markdown]
# ### What is the Profit and Loss across regions ?

# %%
data1= df.groupby("Region")[["Sales","Profit"]].sum().sort_values(by="Sales", ascending=False)
data1[:].plot.bar(color = ["Blue","Red"], figsize=(10,7))
plt.title("Profit-Loss and Sales across Region")
plt.show()

# %% [markdown]
# ### West is a high performing region in Sales and Profit in comparision to the other Regions .

# %% [markdown]
# ### 07 Adding questions to the last exercise.
# #### Q:Which ship mode is the cheapest and best mode which helps in earing more profit ?
#
# #### Q:Which sub categories need to be more advertised ?
#
# #### Q:Whihch are the least performing States and Cities ?

# %% [markdown]
# ### Q8 Hypothesis : If the Sales are increasing over a period then the Profit margin also increases.Work to proove this hypothesis
